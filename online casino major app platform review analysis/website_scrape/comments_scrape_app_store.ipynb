# %%
import pandas as pd
import numpy as np
import json
from app_store_scraper import AppStore
from pprint import pprint
import requests

# %%
betfair = AppStore(country='gb', app_name='betfair-sports-betting', app_id = '552024276')
betfair.review()
# Out:
# 2023-02-07 15:16:46,166 [INFO] Base - Initialised: AppStore('gb', 'betfair-sports-betting', 552024276)
# 2023-02-07 15:16:46,167 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/betfair-sports-betting/id552024276
# 2023-02-07 15:17:05,093 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/gb/apps/552024276/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2023-02-07 15:17:05,098 [INFO] Base - [id:552024276] Fetched 0 reviews (0 fetched in total)

# %%
df_betfair = pd.DataFrame(np.array(betfair.reviews),columns=['review'])
df_betfair_2 = df_betfair.join(pd.DataFrame(df_betfair.pop('review').tolist()))

df_betfair_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
casino888 = AppStore(country='gb', app_name='888-casino-real-money-games', app_id = '586196841')
casino888.review()
# Out:
# 2023-02-07 15:14:38,284 [INFO] Base - Initialised: AppStore('gb', '888-casino-real-money-games', 586196841)
# 2023-02-07 15:14:38,286 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/888-casino-real-money-games/id586196841
# 2023-02-07 15:14:57,064 [INFO] Base - [id:586196841] Fetched 20 reviews (20 fetched in total)
# 2023-02-07 15:15:02,470 [INFO] Base - [id:586196841] Fetched 360 reviews (360 fetched in total)
# 2023-02-07 15:15:08,029 [INFO] Base - [id:586196841] Fetched 780 reviews (780 fetched in total)
# 2023-02-07 15:15:13,362 [INFO] Base - [id:586196841] Fetched 1100 reviews (1100 fetched in total)
# 2023-02-07 15:15:15,328 [INFO] Base - [id:586196841] Fetched 1183 reviews (1183 fetched in total)

# %%
df_casino888 = pd.DataFrame(np.array(casino888.reviews),columns=['review'])
df_casino888_2 = df_casino888.join(pd.DataFrame(df_casino888.pop('review').tolist()))

df_casino888_2
# Out:
#                     date                                  developerResponse  \
# 0    2022-09-12 11:41:11  {'id': 32069767, 'body': 'Hello! Thank you for...
# 1    2022-10-08 23:20:46  {'id': 32540195, 'body': 'Hello! Our Bonuses a...
# 2    2022-07-15 12:44:59  {'id': 31053228, 'body': 'Hello, Alexjwl! The ...
# 3    2020-07-27 15:48:14  {'id': 17045474, 'body': 'Hi! Thanks a lot for...
# 4    2021-04-04 00:21:39  {'id': 22058109, 'body': 'Hi, we are sorry to ...
# ...                  ...                                                ...
# 1178 2015-10-08 16:56:24                                                NaN
# 1179 2015-09-22 11:44:55                                                NaN
# 1180 2015-06-14 14:30:15                                                NaN
# 1181 2015-05-21 18:28:49                                                NaN
# 1182 2015-05-15 03:16:27                                                NaN
#
# ...

# %%
ladbrokes = AppStore(country='gb', app_name='ladbrokes-casino-slots-live', app_id = '1501130082')
ladbrokes.review()
df_ladbrokes = pd.DataFrame(np.array(ladbrokes.reviews),columns=['review'])
df_ladbrokes_2 = df_ladbrokes.join(pd.DataFrame(df_ladbrokes.pop('review').tolist()))

df_ladbrokes_2
# Out:
# 2023-02-07 15:15:16,337 [INFO] Base - Initialised: AppStore('gb', 'ladbrokes-casino-slots-live', 1501130082)
# 2023-02-07 15:15:16,339 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/ladbrokes-casino-slots-live/id1501130082
# 2023-02-07 15:15:17,125 [INFO] Base - [id:1501130082] Fetched 37 reviews (37 fetched in total)
#                   date                                             review  \
# 0  2023-01-24 06:44:28  Loving the free spins after you make your firs...
# 1  2022-10-26 17:42:19  3 years of daily spin ! Every day ! I never go...
# 2  2022-12-02 23:05:25  if your looking for a decent slot site then i ...
# 3  2022-05-08 00:33:14  This is the ideal app if you want to play game...
# 4  2022-10-23 08:06:29  I was enjoying the app quite a bit, loads of d...
# 5  2022-06-24 15:35:36  So easy to use and got all my favourite games!...
# 6  2023-01-27 17:25:33  It’s good app for the slots but having to chan...
# ...

# %%
skybet = AppStore(country='gb', app_name='sky-bet-sports-betting', app_id = '428237841')
skybet.review()
# Out:
# 2023-02-07 15:15:17,578 [INFO] Base - Initialised: AppStore('gb', 'sky-bet-sports-betting', 428237841)
# 2023-02-07 15:15:17,579 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/sky-bet-sports-betting/id428237841
# 2023-02-07 15:15:22,743 [INFO] Base - [id:428237841] Fetched 560 reviews (560 fetched in total)
# 2023-02-07 15:15:27,970 [INFO] Base - [id:428237841] Fetched 1200 reviews (1200 fetched in total)
# 2023-02-07 15:15:33,232 [INFO] Base - [id:428237841] Fetched 1740 reviews (1740 fetched in total)
# 2023-02-07 15:15:38,641 [INFO] Base - [id:428237841] Fetched 2200 reviews (2200 fetched in total)
# 2023-02-07 15:15:44,210 [INFO] Base - [id:428237841] Fetched 2520 reviews (2520 fetched in total)
# ...

# %%
df_skybet = pd.DataFrame(np.array(skybet.reviews),columns=['review'])
df_skybet_2 = df_skybet.join(pd.DataFrame(df_skybet.pop('review').tolist()))

df_skybet_2
# Out:
#                     date                                             review  \
# 0    2019-05-21 22:31:20  Love the app. Would be great to start making t...
# 1    2021-08-17 21:28:37  The sport betting options are levels above mos...
# 2    2018-10-24 21:51:38  Just like it says really. It’s one of the best...
# 3    2017-09-14 13:58:01  I'm a novice at betting and have pretty much w...
# 4    2022-03-26 09:39:17  I loved sky bet , I really enjoyed betting wit...
# ...                  ...                                                ...
# 2755 2013-09-08 18:19:27  Works so well it borders on enabling burgeonin...
# 2756 2013-08-25 13:37:21  Nice new interface , stays logged in for longe...
# 2757 2013-08-16 19:52:08       Easy to use and much better since the update
# 2758 2013-08-05 21:42:43  Brilliant update, but still room for improveme...
# 2759 2013-07-30 13:53:07  Great app, loving the update, was a little con...
#
# ...

# %%
paddypower = AppStore(country='gb', app_name='paddy-power-sports-betting', app_id = '382030091')
paddypower.review()
# Out:
# 2023-02-07 15:16:07,067 [INFO] Base - Initialised: AppStore('gb', 'paddy-power-sports-betting', 382030091)
# 2023-02-07 15:16:07,068 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/paddy-power-sports-betting/id382030091
# 2023-02-07 15:16:25,819 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/gb/apps/382030091/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2023-02-07 15:16:25,822 [INFO] Base - [id:382030091] Fetched 0 reviews (0 fetched in total)

# %%
df_paddypower = pd.DataFrame(np.array(paddypower.reviews),columns=['review'])
df_paddypower_2 = df_paddypower.join(pd.DataFrame(df_paddypower.pop('review').tolist()))

df_paddypower_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
williamhill = AppStore(country='gb', app_name='william-hill-sports-betting', app_id = '465712788')
williamhill.review()
# Out:
# 2023-02-07 15:16:26,569 [INFO] Base - Initialised: AppStore('gb', 'william-hill-sports-betting', 465712788)
# 2023-02-07 15:16:26,570 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/gb/app/william-hill-sports-betting/id465712788
# 2023-02-07 15:16:45,404 [ERROR] Base - Something went wrong: HTTPSConnectionPool(host='amp-api.apps.apple.com', port=443): Max retries exceeded with url: /v1/catalog/gb/apps/465712788/reviews?l=en-GB&offset=0&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac (Caused by ResponseError('too many 429 error responses'))
# 2023-02-07 15:16:45,407 [INFO] Base - [id:465712788] Fetched 0 reviews (0 fetched in total)

# %%
df_williamhill = pd.DataFrame(np.array(williamhill.reviews),columns=['review'])
df_williamhill_2 = df_williamhill.join(pd.DataFrame(df_williamhill.pop('review').tolist()))

df_williamhill_2
# Out:
# Empty DataFrame
# Columns: []
# Index: []
